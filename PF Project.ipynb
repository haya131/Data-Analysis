# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df = pd.read_csv("quality_of_life_dataset.csv")

# %%
df
# Out:
#         Country  Income_Level_USD  Health_Index  Education_Years  \
# 0           USA              5000            85               16
# 1        Canada              4500            88               15
# 2       Germany              4000            82               14
# 3        France              3800            80               13
# 4         India              1200            60               10
# 5         China              1500            65               12
# 6        Brazil              1800            70               11
# 7  South Africa              1300            55                9
# 8         Japan              4200            86               15
# 9     Australia              4600            87               16
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 0                 8                9                Yes         300
# 1                 7                8                Yes         200
# 2                 7                8                Yes         250
# 3                 6                7                Yes         280
# 4                 5                5                 No         500
# 5                 6                6                Yes         450
# 6                 6                6                Yes         600
# 7                 5                4                 No         700
# 8                 7                8                Yes         150
# 9                 8                9                Yes         180
#
#   Internet_Access  Working_Hours_Week  Happiness_Score
# 0             Yes                  40              7.5
# 1             Yes                  38              7.8
# 2             Yes                  39              7.2
# 3             Yes                  37              6.9
# 4              No                  45              5.5
# 5             Yes                  44              6.0
# 6             Yes                  42              6.2
# 7              No                  48              5.0
# 8             Yes                  36              7.4
# 9             Yes                  38              7.7

# %%
df.head()
# Out:
#    Country  Income_Level_USD  Health_Index  Education_Years  Job_Satisfaction  \
# 0      USA              5000            85               16                 8
# 1   Canada              4500            88               15                 7
# 2  Germany              4000            82               14                 7
# 3   France              3800            80               13                 6
# 4    India              1200            60               10                 5
#
#    Housing_Quality Access_Clean_Water  Crime_Rate Internet_Access  \
# 0                9                Yes         300             Yes
# 1                8                Yes         200             Yes
# 2                8                Yes         250             Yes
# 3                7                Yes         280             Yes
# 4                5                 No         500              No
#
#    Working_Hours_Week  Happiness_Score
# 0                  40              7.5
# 1                  38              7.8
# 2                  39              7.2
# 3                  37              6.9
# 4                  45              5.5

# %%
df.tail()
# Out:
#         Country  Income_Level_USD  Health_Index  Education_Years  \
# 5         China              1500            65               12
# 6        Brazil              1800            70               11
# 7  South Africa              1300            55                9
# 8         Japan              4200            86               15
# 9     Australia              4600            87               16
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 5                 6                6                Yes         450
# 6                 6                6                Yes         600
# 7                 5                4                 No         700
# 8                 7                8                Yes         150
# 9                 8                9                Yes         180
#
#   Internet_Access  Working_Hours_Week  Happiness_Score
# 5             Yes                  44              6.0
# 6             Yes                  42              6.2
# 7              No                  48              5.0
# 8             Yes                  36              7.4
# 9             Yes                  38              7.7

# %%
df.describe()
# Out:
#        Income_Level_USD  Health_Index  Education_Years  Job_Satisfaction  \
# count         10.000000     10.000000        10.000000         10.000000
# mean        3190.000000     75.800000        13.100000          6.500000
# std         1540.165936     12.254704         2.514403          1.080123
# min         1200.000000     55.000000         9.000000          5.000000
# 25%         1575.000000     66.250000        11.250000          6.000000
# 50%         3900.000000     81.000000        13.500000          6.500000
# 75%         4425.000000     85.750000        15.000000          7.000000
# max         5000.000000     88.000000        16.000000          8.000000
#
#        Housing_Quality  Crime_Rate  Working_Hours_Week  Happiness_Score
# count        10.000000   10.000000           10.000000        10.000000
# mean          7.000000  361.000000           40.700000         6.720000
# std           1.699673  190.055547            3.917199         0.982966
# min           4.000000  150.000000           36.000000         5.000000
# 25%           6.000000  212.500000           38.000000         6.050000
# 50%           7.500000  290.000000           39.500000         7.050000
# 75%           8.000000  487.500000           43.500000         7.475000
# max           9.000000  700.000000           48.000000         7.800000

# %%
df.shape
# Out:
# (10, 11)

# %%
df.dtypes
# Out:
# Country                 object
# Income_Level_USD      category
# Health_Index             int32
# Education_Years          int64
# Job_Satisfaction         int64
# Housing_Quality          int64
# Access_Clean_Water      object
# Crime_Rate               int64
# Internet_Access         object
# Working_Hours_Week       int64
# Happiness_Score        float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Income_Level_USD', 'Health_Index', 'Education_Years',
#        'Job_Satisfaction', 'Housing_Quality', 'Access_Clean_Water',
#        'Crime_Rate', 'Internet_Access', 'Working_Hours_Week',
#        'Happiness_Score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 4
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Country             10 non-null     object
#  1   Income_Level_USD    10 non-null     category
#  2   Health_Index        10 non-null     int32
#  3   Education_Years     10 non-null     int64
#  4   Job_Satisfaction    10 non-null     int64
#  5   Housing_Quality     10 non-null     int64
#  6   Access_Clean_Water  0 non-null      object
#  7   Crime_Rate          10 non-null     int64
#  8   Internet_Access     0 non-null      object
#  9   Working_Hours_Week  10 non-null     int64
#  10  Happiness_Score     10 non-null     float64
# dtypes: category(1), float64(1), int32(1), int64(5), object(3)
# memory usage: 982.0+ bytes

# %%
df['Crime_Rate']
# Out:
# 0    300
# 9    180
# 1    200
# 8    150
# 2    250
# 3    280
# 6    600
# 5    450
# 7    700
# 4    500
# Name: Crime_Rate, dtype: int64

# %%
df[['Crime_Rate', 'Working_Hours_Week']]
# Out:
#    Crime_Rate  Working_Hours_Week
# 0         300                  40
# 9         180                  38
# 1         200                  38
# 8         150                  36
# 2         250                  39
# 3         280                  37
# 6         600                  42
# 5         450                  44
# 7         700                  48
# 4         500                  45

# %%
df.isnull().sum()
# Out:
# Country               0
# Income_Level_USD      0
# Health_Index          0
# Education_Years       0
# Job_Satisfaction      0
# Housing_Quality       0
# Access_Clean_Water    0
# Crime_Rate            0
# Internet_Access       0
# Working_Hours_Week    0
# Happiness_Score       0
# dtype: int64

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Country, Income_Level_USD, Health_Index, Education_Years, Job_Satisfaction, Housing_Quality, Access_Clean_Water, Crime_Rate, Internet_Access, Working_Hours_Week, Happiness_Score]
# Index: []

# %%
df.dropna(axis=1)
# Out:
#         Country Income_Level_USD  Health_Index  Education_Years  \
# 0           USA             High            85               16
# 9     Australia             High            87               16
# 1        Canada             High            88               15
# 8         Japan             High            86               15
# 2       Germany           Medium            82               14
# 3        France           Medium            80               13
# 6        Brazil              Low            70               11
# 5         China              Low            65               12
# 7  South Africa              Low            55                9
# 4         India              Low            60               10
#
#    Job_Satisfaction  Housing_Quality  Crime_Rate  Working_Hours_Week  \
# 0                 8                9         300                  40
# 9                 8                9         180                  38
# 1                 7                8         200                  38
# 8                 7                8         150                  36
# 2                 7                8         250                  39
# 3                 6                7         280                  37
# 6                 6                6         600                  42
# 5                 6                6         450                  44
# 7                 5                4         700                  48
# 4                 5                5         500                  45
#
#    Happiness_Score
# 0              7.5
# 9              7.7
# 1              7.8
# 8              7.4
# 2              7.2
# 3              6.9
# 6              6.2
# 5              6.0
# 7              5.0
# 4              5.5

# %%
df.rename(columns={'Working_Hours_Week': 'Working_Hours'})
# Out:
#         Country Income_Level_USD  Health_Index  Education_Years  \
# 0           USA             High            85               16
# 9     Australia             High            87               16
# 1        Canada             High            88               15
# 8         Japan             High            86               15
# 2       Germany           Medium            82               14
# 3        France           Medium            80               13
# 6        Brazil              Low            70               11
# 5         China              Low            65               12
# 7  South Africa              Low            55                9
# 4         India              Low            60               10
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 0                 8                9                NaN         300
# 9                 8                9                NaN         180
# 1                 7                8                NaN         200
# 8                 7                8                NaN         150
# 2                 7                8                NaN         250
# 3                 6                7                NaN         280
# 6                 6                6                NaN         600
# 5                 6                6                NaN         450
# 7                 5                4                NaN         700
# 4                 5                5                NaN         500
#
#   Internet_Access  Working_Hours  Happiness_Score
# 0             NaN             40              7.5
# 9             NaN             38              7.7
# 1             NaN             38              7.8
# 8             NaN             36              7.4
# 2             NaN             39              7.2
# 3             NaN             37              6.9
# 6             NaN             42              6.2
# 5             NaN             44              6.0
# 7             NaN             48              5.0
# 4             NaN             45              5.5

# %%
df.drop(columns=['Country'])
# Out:
#    Income_Level_USD  Health_Index  Education_Years  Job_Satisfaction  \
# 0              5000            85               16                 8
# 1              4500            88               15                 7
# 2              4000            82               14                 7
# 3              3800            80               13                 6
# 4              1200            60               10                 5
# 5              1500            65               12                 6
# 6              1800            70               11                 6
# 7              1300            55                9                 5
# 8              4200            86               15                 7
# 9              4600            87               16                 8
#
#    Housing_Quality Access_Clean_Water  Crime_Rate Internet_Access  \
# 0                9                NaN         300             NaN
# 1                8                NaN         200             NaN
# 2                8                NaN         250             NaN
# 3                7                NaN         280             NaN
# 4                5                NaN         500             NaN
# 5                6                NaN         450             NaN
# 6                6                NaN         600             NaN
# 7                4                NaN         700             NaN
# 8                8                NaN         150             NaN
# 9                9                NaN         180             NaN
#
#    Working_Hours_Week  Happiness_Score
# 0                  40              7.5
# 1                  38              7.8
# 2                  39              7.2
# 3                  37              6.9
# 4                  45              5.5
# 5                  44              6.0
# 6                  42              6.2
# 7                  48              5.0
# 8                  36              7.4
# 9                  38              7.7

# %%
df.loc[df['Country'] == 'India', 'Happiness_Score']
# Out:
# 4    5.5
# Name: Happiness_Score, dtype: float64

# %%
df['Country'].value_counts()
# Out:
# Country
# USA             1
# Australia       1
# Canada          1
# Japan           1
# Germany         1
# France          1
# Brazil          1
# China           1
# South Africa    1
# India           1
# Name: count, dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#         Country  Income_Level_USD  Health_Index  Education_Years  \
# 0           USA              5000            85               16
# 1        Canada              4500            88               15
# 2       Germany              4000            82               14
# 3        France              3800            80               13
# 4         India              1200            60               10
# 5         China              1500            65               12
# 6        Brazil              1800            70               11
# 7  South Africa              1300            55                9
# 8         Japan              4200            86               15
# 9     Australia              4600            87               16
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 0                 8                9                NaN         300
# 1                 7                8                NaN         200
# 2                 7                8                NaN         250
# 3                 6                7                NaN         280
# 4                 5                5                NaN         500
# 5                 6                6                NaN         450
# 6                 6                6                NaN         600
# 7                 5                4                NaN         700
# 8                 7                8                NaN         150
# 9                 8                9                NaN         180
#
#   Internet_Access  Working_Hours_Week  Happiness_Score
# 0             NaN                  40              7.5
# 1             NaN                  38              7.8
# 2             NaN                  39              7.2
# 3             NaN                  37              6.9
# 4             NaN                  45              5.5
# 5             NaN                  44              6.0
# 6             NaN                  42              6.2
# 7             NaN                  48              5.0
# 8             NaN                  36              7.4
# 9             NaN                  38              7.7

# %%
df.groupby('Access_Clean_Water')['Income_Level_USD'].mean()
# Out:
# Series([], Name: Income_Level_USD, dtype: float64)

# %%
df.sort_values(by='Income_Level_USD')
# Out:
#         Country  Income_Level_USD  Health_Index  Education_Years  \
# 4         India              1200            60               10
# 7  South Africa              1300            55                9
# 5         China              1500            65               12
# 6        Brazil              1800            70               11
# 3        France              3800            80               13
# 2       Germany              4000            82               14
# 8         Japan              4200            86               15
# 1        Canada              4500            88               15
# 9     Australia              4600            87               16
# 0           USA              5000            85               16
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 4                 5                5                NaN         500
# 7                 5                4                NaN         700
# 5                 6                6                NaN         450
# 6                 6                6                NaN         600
# 3                 6                7                NaN         280
# 2                 7                8                NaN         250
# 8                 7                8                NaN         150
# 1                 7                8                NaN         200
# 9                 8                9                NaN         180
# 0                 8                9                NaN         300
#
#   Internet_Access  Working_Hours_Week  Happiness_Score
# 4             NaN                  45              5.5
# 7             NaN                  48              5.0
# 5             NaN                  44              6.0
# 6             NaN                  42              6.2
# 3             NaN                  37              6.9
# 2             NaN                  39              7.2
# 8             NaN                  36              7.4
# 1             NaN                  38              7.8
# 9             NaN                  38              7.7
# 0             NaN                  40              7.5

# %%
df.sort_values(by=['Happiness_Score', 'Income_Level_USD'])
# Out:
#         Country  Income_Level_USD  Health_Index  Education_Years  \
# 7  South Africa              1300            55                9
# 4         India              1200            60               10
# 5         China              1500            65               12
# 6        Brazil              1800            70               11
# 3        France              3800            80               13
# 2       Germany              4000            82               14
# 8         Japan              4200            86               15
# 0           USA              5000            85               16
# 9     Australia              4600            87               16
# 1        Canada              4500            88               15
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 7                 5                4                NaN         700
# 4                 5                5                NaN         500
# 5                 6                6                NaN         450
# 6                 6                6                NaN         600
# 3                 6                7                NaN         280
# 2                 7                8                NaN         250
# 8                 7                8                NaN         150
# 0                 8                9                NaN         300
# 9                 8                9                NaN         180
# 1                 7                8                NaN         200
#
#   Internet_Access  Working_Hours_Week  Happiness_Score
# 7             NaN                  48              5.0
# 4             NaN                  45              5.5
# 5             NaN                  44              6.0
# 6             NaN                  42              6.2
# 3             NaN                  37              6.9
# 2             NaN                  39              7.2
# 8             NaN                  36              7.4
# 0             NaN                  40              7.5
# 9             NaN                  38              7.7
# 1             NaN                  38              7.8

# %%
df.set_index('Country')['Happiness_Score'].plot(kind='bar')
# Out:
# <Axes: xlabel='Country'>

# %%
df.set_index('Country')['Happiness_Score'].plot(kind='barh')
# Out:
# <Axes: ylabel='Country'>

# %%
df.plot(kind='scatter', x='Income_Level_USD', y='Happiness_Score')
# Out:
# <Axes: xlabel='Income_Level_USD', ylabel='Happiness_Score'>

# %%
df['Health_Index'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Crime_Rate'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[['Income_Level_USD', 'Health_Index']].plot(kind='box')
# Out:
# <Axes: >

# %%
df.plot(kind='line', x='Income_Level_USD', y='Happiness_Score')
# Out:
# <Axes: xlabel='Income_Level_USD'>

# %%
df.plot(kind='area', x='Income_Level_USD', y='Happiness_Score')
# Out:
# <Axes: xlabel='Income_Level_USD'>

# %%
df['Access_Clean_Water'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df.plot(kind='hexbin', x='Income_Level_USD', y='Happiness_Score')
# Out:
# <Axes: xlabel='Income_Level_USD', ylabel='Happiness_Score'>

# %%
df[['Income_Level_USD', 'Happiness_Score']].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Health_Index'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df[['Income_Level_USD', 'Happiness_Score']].plot(kind='line')
# Out:
# <Axes: >

# %%
pd.plotting.scatter_matrix(df, figsize=(10, 6), diagonal='hist')
# Out:
# array([[<Axes: xlabel='Income_Level_USD', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Health_Index', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Education_Years', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Income_Level_USD'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Income_Level_USD'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Health_Index'>,
#         <Axes: xlabel='Health_Index', ylabel='Health_Index'>,
#         <Axes: xlabel='Education_Years', ylabel='Health_Index'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Health_Index'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Health_Index'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Health_Index'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Health_Index'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Health_Index'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Education_Years'>,
#         <Axes: xlabel='Health_Index', ylabel='Education_Years'>,
#         <Axes: xlabel='Education_Years', ylabel='Education_Years'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Education_Years'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Education_Years'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Education_Years'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Education_Years'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Education_Years'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Health_Index', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Education_Years', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Job_Satisfaction'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Job_Satisfaction'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Health_Index', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Education_Years', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Housing_Quality'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Housing_Quality'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Health_Index', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Education_Years', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Crime_Rate'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Crime_Rate'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Health_Index', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Education_Years', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Working_Hours_Week'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Working_Hours_Week'>],
#        [<Axes: xlabel='Income_Level_USD', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Health_Index', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Education_Years', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Job_Satisfaction', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Housing_Quality', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Crime_Rate', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Working_Hours_Week', ylabel='Happiness_Score'>,
#         <Axes: xlabel='Happiness_Score', ylabel='Happiness_Score'>]],
#       dtype=object)

# %%
df.pivot_table(index='Country', columns='Access_Clean_Water', values='Happiness_Score', aggfunc='mean')
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.reset_index
# Out:
# <bound method DataFrame.reset_index of         Country Income_Level_USD  Health_Index  Education_Years  \
# 0           USA             High            85               16
# 9     Australia             High            87               16
# 1        Canada             High            88               15
# 8         Japan             High            86               15
# 2       Germany           Medium            82               14
# 3        France           Medium            80               13
# 6        Brazil              Low            70               11
# 5         China              Low            65               12
# 7  South Africa              Low            55                9
# 4         India              Low            60               10
#
#    Job_Satisfaction  Housing_Quality Access_Clean_Water  Crime_Rate  \
# 0                 8                9                NaN         300
# 9                 8                9                NaN         180
# 1                 7                8                NaN         200
# 8                 7                8                NaN         150
# 2                 7                8                NaN         250
# 3                 6                7                NaN         280
# 6                 6                6                NaN         600
# 5                 6                6                NaN         450
# 7                 5                4                NaN         700
# 4                 5                5                NaN         500
#
#   Internet_Access  Working_Hours  Happiness_Score Success_Rate
# 0             NaN             40              7.5          NaN
# 9             NaN             38              7.7          NaN
# 1             NaN             38              7.8          NaN
# 8             NaN             36              7.4          NaN
# 2             NaN             39              7.2          NaN
# 3             NaN             37              6.9          NaN
# 6             NaN             42              6.2          NaN
# 5             NaN             44              6.0          NaN
# 7             NaN             48              5.0          NaN
# 4             NaN             45              5.5          NaN  >
